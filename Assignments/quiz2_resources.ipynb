# %% [markdown]
# <font size = "10"><span style="color: lightgrey">Quiz 2 Resources</span>

# %%
#import packages
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Question 1
